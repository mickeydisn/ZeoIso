# %%
import shapez2_render as Render 
import shapez2_gameinfo as GlobalInfos 
from shapez2_operation import *

# %%
# !pip install typing-extensions

# %%
class MShape:
    def __init__(self, shapeCode:str) -> None:
        self.shape = Shape.fromShapeCode(shapeCode)
        
    def rotC(self) -> Self:
        shape = rotate90CW(self.shape)[0]
        return MShape(shape.toShapeCode())
    
    def rotAC(self) -> Self:
        shape = rotate90CCW(self.shape)[0]
        return MShape(shape.toShapeCode())

    def rotH(self) -> Self:
        shape = rotate180(self.shape)[0]
        return MShape(shape.toShapeCode())

    def pin(self) -> Self:
        shape = pushPin(self.shape)[0]
        return MShape(shape.toShapeCode())

    def paint(self,color:str) -> Self:
        shape = topPaint(self.shape, color)[0]
        return MShape(shape.toShapeCode())

    def crys(self, color:str) -> Self:
        shape = genCrystal(self.shape, color)[0]
        return MShape(shape.toShapeCode())
    
    def toCode(self) -> str:
        return self.shape.toShapeCode()

    def print(self) -> str:
        layers = self.shape.toListOfLayers()
        layers = [    [s[i:i+2] for i in range(0, len(s), 2)] for s in layers]
        h1, h2 = "", ""
        s1 = ""
        s2 = ""
        for l in range(0, len(layers)):
            h1 += "_____    "
            s1 += layers[l][3] + " " + layers[l][0] + "    "
            s2 += layers[l][2] + " " + layers[l][1] + "    "
            h2 += "⎺⎺⎺⎺⎺    "
        print ('\n'.join([h1, s1, s2, h2]))
        # for layer
        # print(layers)
        # layers.reverse()
        # print ("________\n" + '\n'.join(layers) + "\n⎺⎺⎺⎺⎺⎺⎺⎺")

def cut(s:MShape) -> list[Self]:
    shape = coreCut(s.shape)
    return MShape(shape[0].toShapeCode()), MShape(shape[1].toShapeCode())

def swap(s:MShape, shapeB:Self) -> list[Self]:
    shape = swapHalves(s.shape, shapeB.shape)
    return MShape(shape[0].toShapeCode()), MShape(shape[1].toShapeCode())

def stack(s:MShape, topShape:Self) -> Shape:
    shape = coreStack(s.shape, topShape.shape)
    return MShape(shape[0].toShapeCode())

# %%
Cu = MShape('CuCuCuCu')
Ru = MShape('RuRuRuRu')
Wu = MShape('WuWuWuWu')
Su = MShape('SuSuSuSu')

P = MShape('P-P-P-P-')
X = MShape('XXXXXXXX')
E = MShape('--------')
CY = MShape('cycycycy')

# %%
def cross(s:MShape) -> MShape:
    a, b = cut(s)
    a, b = swap(a.rotC(), b.rotC())
    return a

Ruc = cross(Ru)
Ruc.print()
# Out:
# _____
# -- Ru
# Ru --
# ⎺⎺⎺⎺⎺

# %%
CTX = cross(X).rotC()
CTX.print()

CTPin = cross(P).rotC()
CTPin.print()
CTCrys = cross(CY).rotC()
# Out:
# _____
# XX --
# -- XX
# ⎺⎺⎺⎺⎺
# _____
# P- --
# -- P-
# ⎺⎺⎺⎺⎺

# %%
def cross(s:MShape) -> MShape:
    a, b = cut(s)
    a.rotC().print()
    b.rotC().print()
    a, b = swap(a.rotC(), b.rotC())
    return a

Ruc = cross(Ru)
Ruc.print()
# Out:
# _____
# Ru Ru
# -- --
# ⎺⎺⎺⎺⎺
# _____
# -- --
# Ru Ru
# ⎺⎺⎺⎺⎺
# _____
# -- Ru
# Ru --
# ⎺⎺⎺⎺⎺

# %%
MShape('Cu------:--Cu--Cu:CuCu----:Cu------').print()
# Out:
# _____    _____    _____    _____
# -- Cu    Cu --    -- Cu    -- Cu
# -- --    -- Cu    -- Cu    -- --
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺

# %%
MShape('Cu------:--Cu--Cu:Cu--Cu--:CuCu----').print()
# Out:
# _____    _____    _____    _____
# -- Cu    Cu --    -- Cu    -- Cu
# -- --    -- Cu    Cu --    -- Cu
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺

# %%
MShape('RuCw--Cw:----Ru--').print() # Logo
MShape('CbCuCbCu:Sr------:--CrSrCr:CwCwCwCw').print() # Roquet
MShape('Cu------:--Cu--Cu:Cu--Cu--:--Cu--Cu').print()
MShape('Cu------:--CuCuCu:--Cu----:Cu--CuCu').print()
MShape('--Cr----:----CrRb:--CrRb--').print()

MShape('P-P---P-:CbCuCuCu:P-P-----:--P-crCu:CgCucrCg').print()
# Out:
# _____    _____
# Cw Ru    -- --
# -- Cw    Ru --
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺
# _____    _____    _____    _____
# Cu Cb    -- Sr    Cr --    Cw Cw
# Cb Cu    -- --    Sr Cr    Cw Cw
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺
# _____    _____    _____    _____
# -- Cu    Cu --    -- Cu    Cu --
# -- --    -- Cu    Cu --    -- Cu
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺
# _____    _____    _____    _____
# -- Cu    Cu --    -- --    Cu Cu
# -- --    Cu Cu    -- Cu    Cu --
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺
# _____    _____    _____
# -- --    Rb --    -- --
# -- Cr    Cr --    Rb Cr
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺
# _____    _____    _____    _____    _____
# P- P-    Cu Cb    -- P-    Cu --    Cg Cg
# -- P-    Cu Cu    -- P-    cr P-    cr Cu
# ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺    ⎺⎺⎺⎺⎺

# %% [markdown]
# # Add Draw

# %%
import shaper2_render as Render 
Render.renderShape('CuCuCuCu:CuCuCuCu', 150)._image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import shaper2_render as Render
#       2 Render.renderShape('CuCuCuCu:CuCuCuCu', 150)._image
#
# ModuleNotFoundError: No module named 'shaper2_render'

# %% [markdown]
# # SQL LITE

# %%
a = []

a.append('a')
a.append('b')
a.append('c')
a.append('d')

a.pop(0)
a
# Out:
# ['b', 'c', 'd']

# %%
# Add a new key/value pair
add_key_value('CuCuCuCu', 1, 'start', '', 0, '', 0, 0)

# key = get_first_unchecked_key()
# print_db_count()
# print_db(10)

# print (get_first_unchecked_key())
print("="*100)
print_db_count()

print("="*100)
print (search_exact_shape('CsdqsduRu'))
print (search_exact_shape('CuCuCuCu'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Add a new key/value pair
# ----> 2 add_key_value('CuCuCuCu', 1, 'start', '', 0, '', 0, 0)
#       4 # key = get_first_unchecked_key()
#       5 # print_db_count()
#       6 # print_db(10)
#       7
#       8 # print (get_first_unchecked_key())
#       9 print("="*100)
#
# NameError: name 'add_key_value' is not defined

# %%
# key: str, nlayer:int, op:str, parentA: str="", rotationA:int, parentB: str="", rotationB:int=0, opindex:int=0


def index_shape(mshape:MShape, op:str, parentA, rotA:int, parentB: str, rotB:int, opindex:int=0) -> None:
    a = mshape
    b = a.rotC()
    c = b.rotC()
    d = c.rotC()

    exit_key = any([key_exists(it.toCode()) for it in [a, b , c, d]])

    if (not exit_key):
        add_key_value(mshape.toCode(), mshape.shape.numLayers, op, parentA, rotA, parentB, rotB, opindex)


def apply_shape_function():
    shapeCode = get_first_unchecked_key()
    if (not shapeCode):
        print ('####################### UncheckCode Not Found ##################################### ')
        return False

    mshape = MShape(shapeCode)
    # index_shape(mshape.rotC(), 'rot', shapeCode, '', 0)   
    
    index_shape(mshape.pin(), 'pin', parentA=shapeCode, rotA=0, parentB='', rotB=0, opindex=0)   
    index_shape(mshape.crys("r"), 'crys', parentA=shapeCode, rotA=0, parentB='', rotB=0, opindex=0)   

    a, b = cut(mshape)
    index_shape(a, 'cut', parentA=shapeCode, rotA=0, parentB='', rotB=0, opindex=0)   
    index_shape(b, 'cut', parentA=shapeCode, rotA=0, parentB='', rotB=0, opindex=1)   
    a, b = cut(mshape.rotC())
    index_shape(a, 'cut', parentA=shapeCode, rotA=1, parentB='', rotB=0, opindex=0)   
    index_shape(b, 'cut', parentA=shapeCode, rotA=1, parentB='', rotB=0, opindex=1)   

    nlayer = mshape.shape.numLayers
    if (nlayer > 1): 
        set_ischeck(shapeCode)
        return True

    for it in keyCheckLayerMax:
        shapeCodeB = it
        mshapeB = MShape(shapeCodeB)
        a, b = swap(mshape, mshapeB)
        index_shape(a, 'swap', parentA=shapeCode, rotA=0, parentB=shapeCodeB, rotB=0, opindex=0)   
        index_shape(b, 'swap', parentA=shapeCode, rotA=0, parentB=shapeCodeB, rotB=0, opindex=1)   

        a = stack(mshape, mshapeB)
        index_shape(a, 'stack', parentA=shapeCode, rotA=0, parentB=shapeCodeB, rotB=0, opindex=0) 
        a = stack(mshape, mshapeB.rotC())
        index_shape(a, 'stack', parentA=shapeCode, rotA=0, parentB=shapeCodeB, rotB=1, opindex=0) 
        a = stack(mshape, mshapeB.rotH())
        index_shape(a, 'stack', parentA=shapeCode, rotA=0, parentB=shapeCodeB, rotB=2, opindex=0) 
        a = stack(mshape, mshapeB.rotAC())
        index_shape(a, 'stack', parentA=shapeCode, rotA=0, parentB=shapeCodeB, rotB=3, opindex=0) 

        b = stack(mshape, mshapeB)
        index_shape(b, 'stack', parentA=shapeCodeB, rotA=0, parentB=shapeCode, rotB=0, opindex=0) 
        b = stack(mshape, mshapeB.rotC())
        index_shape(b, 'stack', parentA=shapeCodeB, rotA=0, parentB=shapeCode, rotB=1, opindex=0) 
        b = stack(mshape, mshapeB.rotH())
        index_shape(b, 'stack', parentA=shapeCodeB, rotA=0, parentB=shapeCode, rotB=2, opindex=0) 
        b = stack(mshape, mshapeB.rotAC())
        index_shape(b, 'stack', parentA=shapeCodeB, rotA=0, parentB=shapeCode, rotB=3, opindex=0) 


    set_ischeck(shapeCode)
    return True

# %%
from IPython.display import clear_output
import time



i = 0
while True:
    i += 1
    isapply = apply_shape_function()
    if (not isapply):
        print('no shape to find')
        break
    if (i % 100 == 0):
        # clear_output(wait=True)
        print('---------------------------', i)
        print_db_count()

# print_db(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 70
#      68 while True:
#      69     i += 1
# ---> 70     isapply = apply_shape_function()
#      71     if (not isapply):
#      72         print('no shape to find')
#
# Cell In[14], line 17, in apply_shape_function()
#      16 def apply_shape_function():
# ---> 17     shapeCode = get_first_unchecked_key()
#      18     if (not shapeCode):
#      19         print ('####################### UncheckCode Not Found ##################################### ')
#
# Cell In[16], line 35, in get_first_unchecked_key()
#      34 def get_first_unchecked_key() -> str:
# ---> 35     return keyUncheck.pop()
#
# IndexError: pop from empty list

# %%
[key for key in keyCheck]
# Out:
# ['CuCuCuCu',
#  '----CuCu',
#  '----CuCu:CuCuCuCu',
#  'Cu------:CuCu----',
#  '--Cu----:--Cu----',
#  'crCucrcr:crCucrcr',
#  'P-P-P-P-:crCucrcr:crCucrcr',
#  '----P-P-:----Cu--:----Cu--',
#  'P-------',
#  'P---CuCu:----CuCu',
#  'CuP-----:Cu------',
#  'P-P-----:CuP-----:Cu------',
#  'P-P-----:P-P-----:CuP-----:Cu------',
#  '--P-----:--P-----:--Cu----:--Cu----',
#  '--P-----:--P-----:--P-----:--Cu----',
#  'crcrcrcr:crcrcrcr:crcrcrcr:crCucrcr',
#  'P-P-P-P-',
#  'P-P-P-P-:P-------',
#  'P-P-----:--P-----',
#  'P-P-----:P-P-----:--P-----',
#  'crcrcrcr:crcrcrcr:crcrcrcr',
#  'P-P-P-P-:crcrcrcr:crcrcrcr:crcrcrcr',
#  'crcrcrcr:crcrcrcr:crcrcrcr:crcrcrcr',
#  'P-P-----:P-P-----:P-P-----:--P-----',
#  'P-P-----:P-P-----:P-P-----:P-P-----',
#  'P-P-----:P-------',
#  'P-P-----:P-P-----:P-------',
#  'P-P-----:P-P-----:P-P-----:P-------',
#  'crcrcrcr:crcrcrcr',
#  'P-P-P-P-:crcrcrcr:crcrcrcr',
#  'P-P-P-P-:P-P-P-P-:crcrcrcr:crcrcrcr',
#  '----P-P-:----P-P-',
#  '----P-P-:----P-P-:----P-P-',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:P-P-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-------',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:P-------',
#  'P---P-P-',
#  'P---P-P-:P-------',
#  'P---P-P-:P---P-P-:P-------',
#  'P---P-P-:P---P-P-:P---P-P-:P-------',
#  'P---P-P-:P---P-P-:P---P-P-:P---P-P-',
#  'P---P-P-:--CuCu--',
#  '------P-:----CuCu',
#  'P-------:Cu------',
#  'crcrcrcr:Cucrcrcr',
#  'P-P-P-P-:crcrcrcr:Cucrcrcr',
#  'P-P-----:--Cu----',
#  'P-P-----:P-P-----:--Cu----',
#  'P-P-----:P-P-----:P-P-----:--Cu----',
#  'crcrcrcr:crcrcrcr:Cucrcrcr',
#  'P-P-P-P-:crcrcrcr:crcrcrcr:Cucrcrcr',
#  'P-P-P-P-:P-P-P-P-:crcrcrcr:Cucrcrcr',
#  'P-P-----:P-P-----:Cu------',
#  'P-P-----:P-P-----:P-P-----:Cu------',
#  'P-------:P-------:Cu------',
#  '------P-:------P-:----CuCu',
#  'crcrcrcr:crcrcrcr:crcrCuCu',
#  'P-P-P-P-:crcrcrcr:crcrcrcr:crcrCuCu',
#  'crcrcrcr:crcrcrcr:crcrcrcr:crcrCuCu',
#  '------P-:------P-:------P-:----CuCu',
#  'P-Cu----',
#  'P-CuCuCu:--P-P-P-',
#  'CuP-----:P-------',
#  '--Cu----:--P-----',
#  '--P-----:--Cu----:--P-----',
#  'crcrcrcr:crCucrcr:crcrcrcr',
#  'P-P-P-P-:crcrcrcr:crCucrcr:crcrcrcr',
#  'crcrcrcr:crCucrcr:crcrcrcr:crcrcrcr',
#  'crCucrcr:crcrcrcr:crcrcrcr:crcrcrcr',
#  'P-P-P-P-:--Cu----',
#  'P-P-P-P-:P-P-P-P-:--Cu----',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:--Cu----',
#  '--P-----:--P-----:--Cu----:--P-----',
#  'crcrcrcr:crcrcrcr:crCucrcr:crcrcrcr',
#  'Cucrcrcr:crcrcrcr',
#  'P-P-P-P-:Cucrcrcr:crcrcrcr',
#  'P-P-P-P-:P-P-P-P-:Cucrcrcr:crcrcrcr',
#  'P-P-----:CuP-----:P-------',
#  'P-P-----:P-P-----:CuP-----:P-------',
#  'P-Cu----:--P-----',
#  'P-P-----:P-Cu----:--P-----',
#  'P-P-----:P-P-----:P-Cu----:--P-----',
#  'P-P-----:P-P-----:P-P-----:P-Cu----',
#  '----CuCu:----P-P-',
#  'crcrCuCu:crcrcrcr',
#  'P-P-P-P-:crcrCuCu:crcrcrcr',
#  'crcrcrcr:crcrCuCu:crcrcrcr',
#  'P-P-P-P-:crcrcrcr:crcrCuCu:crcrcrcr',
#  'crcrcrcr:crcrCuCu:crcrcrcr:crcrcrcr',
#  'crcrCuCu:crcrcrcr:crcrcrcr:crcrcrcr',
#  'P-P-P-P-:P-P-P-P-:----CuCu',
#  '----P-P-:----P-P-:----CuCu',
#  '----P-P-:----P-P-:----P-P-:----CuCu',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:----CuCu',
#  'P-P-P-P-:P-P-P-P-:crcrCuCu:crcrcrcr',
#  'crcrcrcr:crcrcrcr:crcrCuCu:crcrcrcr',
#  '----P-P-:----CuCu:----P-P-',
#  '----P-P-:----P-P-:----CuCu:----P-P-',
#  'crCuCuCu:crcrcrcr',
#  'P-P-P-P-:crCuCuCu:crcrcrcr',
#  'crcrcrcr:crCuCuCu:crcrcrcr',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:crcrcrcr',
#  'crcrcrcr:crCuCuCu:crcrcrcr:crcrcrcr',
#  'crCuCuCu:crcrcrcr:crcrcrcr:crcrcrcr',
#  'P-P-P-P-:--CuCuCu',
#  'crcrcrcr:crCuCuCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu',
#  'P-P-P-P-:crcrcrcr:crcrcrcr:crCuCuCu',
#  'crcrcrcr:crcrcrcr:crcrcrcr:crCuCuCu',
#  'P-P-P-P-:P-P-P-P-:crcrcrcr:crCuCuCu',
#  'P-P-P-P-:P-P-P-P-:--CuCuCu',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:--CuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:crcrcrcr',
#  'crcrcrcr:crcrcrcr:crCuCuCu:crcrcrcr',
#  'P-P-P-P-:P-CuCuCu:--P-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:--P-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:P-CuCuCu',
#  'P-CuCuCu:P-P-P---',
#  'CuP-----:--P-----',
#  'P-P-----:CuP-----:--P-----',
#  'P-P-----:P-P-----:CuP-----:--P-----',
#  'P-Cu----:P-P-----',
#  'P-P-----:P-Cu----:P-P-----',
#  'P-P-----:P-P-----:P-Cu----:P-P-----',
#  '----CuCu:----P---',
#  '----P-P-:----CuCu:----P---',
#  '----P-P-:----P-P-:----CuCu:----P---',
#  'P-P-P-P-:P-CuCuCu:P-P-P---',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P-P-P---',
#  'P-CuCuCu:P-P---P-',
#  'CuP-----:P-P-----',
#  'P-P-----:CuP-----:P-P-----',
#  'P-P-----:P-P-----:CuP-----:P-P-----',
#  '----CuCu:------P-',
#  '----P-P-:----CuCu:------P-',
#  '----P-P-:----P-P-:----CuCu:------P-',
#  'P-P-P-P-:P-CuCuCu:P-P---P-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P-P---P-',
#  'P-CuCuCu:P---P-P-',
#  'P-Cu----:P-------',
#  'P-P-----:P-Cu----:P-------',
#  'P-P-----:P-P-----:P-Cu----:P-------',
#  'P-P-P-P-:P-CuCuCu:P---P-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P---P-P-',
#  'P-CuCuCu:P-P-P-P-',
#  'P-P-P-P-:P-CuCuCu:P-P-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P-P-P-P-',
#  'P-CuP-P-',
#  'P-CuP-P-:Cu----P-',
#  'P-Cu----:Cu------',
#  'P-P-----:P-Cu----:Cu------',
#  'crcrcrcr:crCucrcr:Cucrcrcr',
#  'P-P-P-P-:crcrcrcr:crCucrcr:Cucrcrcr',
#  'crcrcrcr:crCucrcr:crcrcrcr:Cucrcrcr',
#  'crCucrcr:crcrcrcr:crcrcrcr:Cucrcrcr',
#  'P-P-----:P-P-----:P-Cu----:Cu------',
#  'crcrcrcr:crcrcrcr:crCucrcr:Cucrcrcr',
#  'crCucrcr:Cucrcrcr',
#  'P-P-P-P-:crCucrcr:Cucrcrcr',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:Cucrcrcr',
#  'P-P-P-P-:P-CuP-P-:Cu----P-',
#  'P-P-----:P-P-----:P-Cu----',
#  '----P-P-:----CuP-',
#  '----P-P-:----P-P-:----CuP-',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:Cu----P-',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:P-CuP-P-',
#  'P-CuP-P-:----P-Cu',
#  'crCucrcr:crcrcrCu',
#  'P-P-P-P-:crCucrcr:crcrcrCu',
#  'crcrcrcr:crCucrcr:crcrcrCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:crcrcrCu',
#  'crcrcrcr:crCucrcr:crcrcrcr:crcrcrCu',
#  'crCucrcr:crcrcrcr:crcrcrcr:crcrcrCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:crcrcrCu',
#  'crcrcrcr:crcrcrcr:crCucrcr:crcrcrCu',
#  'P-P-P-P-:P-CuP-P-:----P-Cu',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:----P-Cu',
#  'P-CuP-P-:--P-Cu--',
#  '----CuP-:----P-Cu',
#  '----P-P-:----CuP-:----P-Cu',
#  'crcrcrcr:crcrCucr:crcrcrCu',
#  'P-P-P-P-:crcrcrcr:crcrCucr:crcrcrCu',
#  'crcrcrcr:crcrCucr:crcrcrcr:crcrcrCu',
#  'crcrCucr:crcrcrcr:crcrcrcr:crcrcrCu',
#  '----P-P-:----P-P-:----CuP-:----P-Cu',
#  'crcrcrcr:crcrcrcr:crcrCucr:crcrcrCu',
#  'crCucrcr:crcrCucr',
#  'P-P-P-P-:crCucrcr:crcrCucr',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:crcrCucr',
#  'P-P-P-P-:P-CuP-P-:--P-Cu--',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:--P-Cu--',
#  'P-CuP-P-:P-Cu----',
#  'P-Cu----:P-Cu----',
#  'P-P-----:P-Cu----:P-Cu----',
#  'P-P-----:P-P-----:P-Cu----:P-Cu----',
#  'P-P-P-P-:P-CuP-P-:P-Cu----',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:P-Cu----',
#  'P-CuP-P-:--P-P-P-',
#  'P-P-P-P-:P-CuP-P-:--P-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:--P-P-P-',
#  'P-CuP-P-:P-P-P---',
#  'P-P-P-P-:P-CuP-P-:P-P-P---',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:P-P-P---',
#  'P-CuP-P-:P-P---P-',
#  'P-P-P-P-:P-CuP-P-:P-P---P-',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:P-P---P-',
#  'P-CuP-P-:P---P-P-',
#  'P-P-P-P-:P-CuP-P-:P---P-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:P---P-P-',
#  'P-CuP-P-:P-P-P-P-',
#  'P-P-P-P-:P-CuP-P-:P-P-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:P-P-P-P-',
#  'P-CuP-P-:------P-',
#  'P-P-P-P-:P-CuP-P-:------P-',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:------P-',
#  'P-CuP-P-:----P---',
#  'P-P-P-P-:P-CuP-P-:----P---',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:----P---',
#  'P-CuP-P-:--P-----',
#  'P-P-P-P-:P-CuP-P-:--P-----',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:--P-----',
#  'P-CuP-P-:P-------',
#  'P-P-P-P-:P-CuP-P-:P-------',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:P-------',
#  'P-CuP-P-:--CuCu--',
#  '----CuP-:----CuCu',
#  '----P-P-:----CuP-:----CuCu',
#  'crcrcrcr:crcrCucr:crcrCuCu',
#  'P-P-P-P-:crcrcrcr:crcrCucr:crcrCuCu',
#  '----P-P-:----Cu--:----CuCu',
#  '----P-P-:----P-P-:----Cu--:----CuCu',
#  'crcrcrcr:crcrcrcr:crcrCucr:crcrCuCu',
#  'crcrCucr:crcrcrcr:crcrcrcr:crcrCuCu',
#  'crcrcrcr:crcrCucr:crcrcrcr:crcrCuCu',
#  '----P-P-:----P-P-:----CuP-:----CuCu',
#  'P-Cu----:--Cu----',
#  'P-P-----:P-Cu----:--Cu----',
#  'P-P-----:P-P-----:P-Cu----:--Cu----',
#  'P-P-P-P-:P-CuP-P-:--CuCu--',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:--CuCu--',
#  'P-CuP-P-:CuCu----',
#  'P-Cu----:CuCu----',
#  'P-P-----:P-Cu----:CuCu----',
#  'crcrcrcr:crCucrcr:CuCucrcr',
#  'P-P-P-P-:crcrcrcr:crCucrcr:CuCucrcr',
#  'P-P-----:--Cu----:CuCu----',
#  'P-P-----:P-P-----:--Cu----:CuCu----',
#  'crcrcrcr:crcrcrcr:crCucrcr:CuCucrcr',
#  'crCucrcr:crcrcrcr:crcrcrcr:CuCucrcr',
#  'crcrcrcr:crCucrcr:crcrcrcr:CuCucrcr',
#  'P-P-----:P-P-----:P-Cu----:CuCu----',
#  'crCucrcr:CuCucrcr',
#  'P-P-P-P-:crCucrcr:CuCucrcr',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:CuCucrcr',
#  'P-P-P-P-:P-CuP-P-:CuCu----',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:CuCu----',
#  'P-CuP-P-:Cu----Cu',
#  'crCucrcr:CucrcrCu',
#  'P-P-P-P-:crCucrcr:CucrcrCu',
#  'crcrcrcr:crCucrcr:CucrcrCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:CucrcrCu',
#  'crcrcrcr:crCucrcr:crcrcrcr:CucrcrCu',
#  'crCucrcr:crcrcrcr:crcrcrcr:CucrcrCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:CucrcrCu',
#  'crcrcrcr:crcrcrcr:crCucrcr:CucrcrCu',
#  'P-P-P-P-:P-CuP-P-:Cu----Cu',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:Cu----Cu',
#  'P-CuP-P-:----CuCu',
#  '----CuP-:------Cu',
#  '----P-P-:----CuP-:------Cu',
#  '----P-P-:----P-P-:----CuP-:------Cu',
#  'crCucrcr:crcrCuCu',
#  'P-P-P-P-:crCucrcr:crcrCuCu',
#  'crcrcrcr:crCucrcr:crcrCuCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:crcrCuCu',
#  'crcrcrcr:crCucrcr:crcrcrcr:crcrCuCu',
#  'crCucrcr:crcrcrcr:crcrcrcr:crcrCuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:crcrCuCu',
#  'P-P-----:P-P-----:--Cu----:crcr----',
#  'crcrcrcr:crcrcrcr:crCucrcr:crcrCuCu',
#  'P-P-P-P-:P-CuP-P-:----CuCu',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:----CuCu',
#  'P-CuP-P-:CuCuCuCu',
#  'crCucrcr:CuCuCuCu',
#  'P-P-P-P-:crCucrcr:CuCuCuCu',
#  'crcrcrcr:crCucrcr:CuCuCuCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:CuCuCuCu',
#  'crcrcrcr:crcrcrcr:crCucrcr:CuCuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:CuCuCuCu',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:crCucrcr',
#  'P-P-P-P-:P-CuP-P-:CuCuCuCu',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-:CuCuCuCu',
#  '----CuP-',
#  'CuCuCuP-:CuP-P-P-',
#  'CuCu----:CuP-----',
#  'CuCucrcr:Cucrcrcr',
#  'CuCu----:Cu------',
#  'P-P-----:CuCu----:Cu------',
#  'crcrcrcr:CuCucrcr:Cucrcrcr',
#  'P-P-P-P-:crcrcrcr:CuCucrcr:Cucrcrcr',
#  'crcrcrcr:CuCucrcr:crcrcrcr:Cucrcrcr',
#  'CuCucrcr:crcrcrcr:crcrcrcr:Cucrcrcr',
#  'P-P-----:P-P-----:CuCu----:Cu------',
#  'crcrcrcr:crcrcrcr:CuCucrcr:Cucrcrcr',
#  'P-P-P-P-:CuCucrcr:Cucrcrcr',
#  'P-P-P-P-:P-P-P-P-:CuCucrcr:Cucrcrcr',
#  'P-P-----:P-P-----:--Cu----:--Cu----',
#  'P-P-----:CuCu----:CuP-----',
#  'P-P-----:P-P-----:CuCu----:CuP-----',
#  'CuCuCucr:Cucrcrcr',
#  'P-P-P-P-:CuCuCucr:Cucrcrcr',
#  'crcrcrcr:CuCuCucr:Cucrcrcr',
#  'P-P-P-P-:crcrcrcr:CuCuCucr:Cucrcrcr',
#  'crcrcrcr:CuCuCucr:crcrcrcr:Cucrcrcr',
#  'CuCuCucr:crcrcrcr:crcrcrcr:Cucrcrcr',
#  'P-P-P-P-:P-P-P-P-:CuCuCucr:Cucrcrcr',
#  'crcrcrcr:crcrcrcr:CuCuCucr:Cucrcrcr',
#  'P-P-P-P-:CuCuCuP-:CuP-P-P-',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:CuP-P-P-',
#  'CuCuCuP-:P-P-P-Cu',
#  'P-Cu----:CuP-----',
#  'P-P-----:P-Cu----:CuP-----',
#  'P-P-----:P-P-----:P-Cu----:CuP-----',
#  'CuCuCucr:crcrcrCu',
#  'crCu----:Cu------',
#  '--cr----:--Cu----',
#  '--P-----:--cr----:--Cu----',
#  '--P-----:--P-----:--cr----:--Cu----',
#  '--P-----:--P-----:--P-----:--cr----',
#  'P-P-----:crCu----:Cu------',
#  'P-P-----:P-P-----:crCu----:Cu------',
#  'P-P-----:P-P-----:P-P-----:crCu----',
#  '----Cucr:------Cu',
#  '----P-P-:----Cucr:------Cu',
#  '----P-P-:----P-P-:----Cucr:------Cu',
#  '----P-P-:----P-P-:----P-P-:----Cucr',
#  'P-P-P-P-:CuCuCucr:crcrcrCu',
#  'crcrcrcr:CuCuCucr:crcrcrCu',
#  'P-P-P-P-:crcrcrcr:CuCuCucr:crcrcrCu',
#  'crcrcrcr:crcrcrcr:CuCuCucr:crcrcrCu',
#  'P-P-P-P-:P-P-P-P-:CuCuCucr:crcrcrCu',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:CuCuCucr',
#  'P-P-P-P-:CuCuCuP-:P-P-P-Cu',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:P-P-P-Cu',
#  'CuCuCuP-:P-P-CuP-',
#  '----CuCu:----P-Cu',
#  'crcrCuCu:crcrcrCu',
#  '----CuCu:------Cu',
#  '----P-P-:----CuCu:------Cu',
#  'crcrcrcr:crcrCuCu:crcrcrCu',
#  'P-P-P-P-:crcrcrcr:crcrCuCu:crcrcrCu',
#  'crcrcrcr:crcrCuCu:crcrcrcr:crcrcrCu',
#  'crcrCuCu:crcrcrcr:crcrcrcr:crcrcrCu',
#  '----P-P-:----P-P-:----CuCu:------Cu',
#  'crcrcrcr:crcrcrcr:crcrCuCu:crcrcrCu',
#  'P-P-P-P-:crcrCuCu:crcrcrCu',
#  'P-P-P-P-:P-P-P-P-:crcrCuCu:crcrcrCu',
#  '----P-P-:----CuCu:----P-Cu',
#  '----P-P-:----P-P-:----CuCu:----P-Cu',
#  '----CuP-:----CuP-',
#  '----P-P-:----CuP-:----CuP-',
#  '----P-P-:----P-P-:----CuP-:----CuP-',
#  'CuCuCucr:crcrCucr',
#  'P-P-P-P-:CuCuCucr:crcrCucr',
#  'crcrcrcr:CuCuCucr:crcrCucr',
#  'P-P-P-P-:crcrcrcr:CuCuCucr:crcrCucr',
#  'crcrcrcr:CuCuCucr:crcrcrcr:crcrCucr',
#  'CuCuCucr:crcrcrcr:crcrcrcr:crcrCucr',
#  'P-P-P-P-:P-P-P-P-:CuCuCucr:crcrCucr',
#  'crcrcrcr:crcrcrcr:CuCuCucr:crcrCucr',
#  'P-P-P-P-:CuCuCuP-:P-P-CuP-',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:P-P-CuP-',
#  'CuCuCuP-:P-CuP-P-',
#  'CuCuCucr:crCucrcr',
#  'P-P-P-P-:CuCuCucr:crCucrcr',
#  'crcrcrcr:CuCuCucr:crCucrcr',
#  'P-P-P-P-:crcrcrcr:CuCuCucr:crCucrcr',
#  'crcrcrcr:CuCuCucr:crcrcrcr:crCucrcr',
#  'CuCuCucr:crcrcrcr:crcrcrcr:crCucrcr',
#  'P-P-P-P-:P-P-P-P-:CuCuCucr:crCucrcr',
#  'crcrcrcr:crcrcrcr:CuCuCucr:crCucrcr',
#  'P-P-P-P-:CuCuCuP-:P-CuP-P-',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:P-CuP-P-',
#  'CuCuCuP-:Cu----P-',
#  'P-P-P-P-:CuCuCuP-:Cu----P-',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:Cu----P-',
#  'CuCuCuP-:----P-Cu',
#  'P-P-P-P-:CuCuCuP-:----P-Cu',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:----P-Cu',
#  'CuCuCuP-:--P-Cu--',
#  'P-P-P-P-:CuCuCuP-:--P-Cu--',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:--P-Cu--',
#  'CuCuCuP-:P-Cu----',
#  'P-P-P-P-:CuCuCuP-:P-Cu----',
#  'P-P-P-P-:P-P-P-P-:CuCuCuP-:P-Cu----',
#  'P---CuP-',
#  'P-P-CuP-:--CuP---',
#  'P-P-P-P-:P-P-CuP-:--CuP---',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:--CuP---',
#  'P-P-CuP-:CuP-----',
#  'P-P-P-P-:P-P-CuP-:CuP-----',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:CuP-----',
#  'P-P-CuP-:P-----Cu',
#  'P-P-P-P-:P-P-CuP-:P-----Cu',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:P-----Cu',
#  'P-P-CuP-:----CuP-',
#  'P-P-P-P-:P-P-CuP-:----CuP-',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:----CuP-',
#  'P-P-CuP-:CuP-P-P-',
#  'P-P-P-P-:P-P-CuP-:CuP-P-P-',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:CuP-P-P-',
#  'P-P-CuP-:P-P-P-Cu',
#  'P-P-P-P-:P-P-CuP-:P-P-P-Cu',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:P-P-P-Cu',
#  'P-P-CuP-:P-P-CuP-',
#  'P-P-P-P-:P-P-CuP-:P-P-CuP-',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:P-P-CuP-',
#  'P-P-CuP-:P-CuP-P-',
#  'P-P-P-P-:P-P-CuP-:P-CuP-P-',
#  'P-P-P-P-:P-P-P-P-:P-P-CuP-:P-CuP-P-',
#  'P---CuP-:P-------',
#  'P---P-P-:P---CuP-:P-------',
#  'P---P-P-:P---P-P-:P---CuP-:P-------',
#  'P---P-P-:P---P-P-:P---P-P-:P---CuP-',
#  'P---CuP-:--CuCu--',
#  'P---P-P-:P---CuP-:--CuCu--',
#  '------P-:------Cu:----CuCu',
#  '------P-:------P-:------Cu:----CuCu',
#  'P---P-P-:P---P-P-:P---CuP-:--CuCu--',
#  'P-Cu----:P-------:P-------',
#  'crCucrcr:crcrcrcr:crcrcrcr',
#  'P-P-P-P-:crCucrcr:crcrcrcr:crcrcrcr',
#  'P-P-----:P-Cu----:P-------:P-------',
#  'P---CuP-:CuCu----',
#  'P-------:CuCu----',
#  'P-------:P-------:CuCu----',
#  'P-------:P-------:P-------:CuCu----',
#  'P---P-P-:P---CuP-:CuCu----',
#  'P---P-P-:P---P-P-:P---CuP-:CuCu----',
#  '----CuP-:------P-:------Cu',
#  'crcrCucr:crcrcrcr:crcrcrCu',
#  'P-P-P-P-:crcrCucr:crcrcrcr:crcrcrCu',
#  '----P-P-:----CuP-:------P-:------Cu',
#  'P---CuP-:Cu----Cu',
#  'P---P-P-:P---CuP-:Cu----Cu',
#  'P---P-P-:P---P-P-:P---CuP-:Cu----Cu',
#  'P---CuP-:----CuCu',
#  'P---P-P-:P---CuP-:----CuCu',
#  'P---P-P-:P---P-P-:P---CuP-:----CuCu',
#  'P---CuP-:CuCuCuCu',
#  'P---P-P-:P---CuP-:CuCuCuCu',
#  'P---P-P-:P---P-P-:P---CuP-:CuCuCuCu',
#  'P---P-P-:P---CuP-',
#  'P---P-P-:P---P-P-:P---CuP-',
#  '----CuP-:Cu----Cu',
#  '----P-P-:----CuP-:Cu----Cu',
#  '----P-P-:----P-P-:----CuP-:Cu----Cu',
#  '----CuP-:CuCuCuCu',
#  '----P-P-:----CuP-:CuCuCuCu',
#  '----P-P-:----P-P-:----CuP-:CuCuCuCu',
#  'P-P-P-P-:P-CuP-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuP-P-',
#  'P-CuCuCu:------P-',
#  'P-P-P-P-:P-CuCuCu:------P-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:------P-',
#  'P-CuCuCu:----P---',
#  'P-P-P-P-:P-CuCuCu:----P---',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:----P---',
#  'P-CuCuCu:--P-----',
#  'P-P-P-P-:P-CuCuCu:--P-----',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:--P-----',
#  'P-CuCuCu:P-------',
#  'P-P-P-P-:P-CuCuCu:P-------',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P-------',
#  'P-CuCuCu:----CuCu',
#  'crCuCuCu:crcrCuCu',
#  'crCu----:crcr----',
#  'P-P-----:crCu----:crcr----',
#  'P-P-----:P-P-----:crCu----:crcr----',
#  'P-P-P-P-:crCuCuCu:crcrCuCu',
#  '----P-P-:----CuCu:----CuCu',
#  'crcrcrcr:crcrCuCu:crcrCuCu',
#  'P-P-P-P-:crcrcrcr:crcrCuCu:crcrCuCu',
#  'crcrcrcr:crcrCuCu:crcrcrcr:crcrCuCu',
#  'crcrCuCu:crcrcrcr:crcrcrcr:crcrCuCu',
#  '----P-P-:----P-P-:----CuCu:----CuCu',
#  'crcrcrcr:crcrcrcr:crcrCuCu:crcrCuCu',
#  'crcrcrcr:crCuCuCu:crcrCuCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:crcrCuCu',
#  'crcrcrcr:crCuCuCu:crcrcrcr:crcrCuCu',
#  'crCuCuCu:crcrcrcr:crcrcrcr:crcrCuCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:crcrCuCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu:crcrCuCu',
#  'P-P-P-P-:P-CuCuCu:----CuCu',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:----CuCu',
#  'P-CuCuCu:--CuCu--',
#  'crCuCuCu:crCuCucr',
#  'P-P-P-P-:crCuCuCu:crCuCucr',
#  'crcrcrcr:crCuCuCu:crCuCucr',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:crCuCucr',
#  'crcrcrcr:crCuCuCu:crcrcrcr:crCuCucr',
#  'crCuCuCu:crcrcrcr:crcrcrcr:crCuCucr',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:crCuCucr',
#  'crcrcrcr:crcrcrcr:crCuCuCu:crCuCucr',
#  'P-P-P-P-:P-CuCuCu:--CuCu--',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:--CuCu--',
#  'P-CuCuCu:CuCu----',
#  'crCuCuCu:CuCucrcr',
#  'crCu----:CuCu----',
#  'P-P-----:crCu----:CuCu----',
#  'P-P-----:P-P-----:crCu----:CuCu----',
#  '----CuCu:----crcr',
#  '----P-P-:----CuCu:----crcr',
#  '----P-P-:----P-P-:----CuCu:----crcr',
#  'P-P-P-P-:crCuCuCu:CuCucrcr',
#  'crcrcrcr:crCuCuCu:CuCucrcr',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:CuCucrcr',
#  'crcrcrcr:crcrcrcr:crCuCuCu:CuCucrcr',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CuCucrcr',
#  'P-P-P-P-:P-CuCuCu:CuCu----',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:CuCu----',
#  'P-CuCuCu:Cu----Cu',
#  'crCuCuCu:CucrcrCu',
#  'Cucr----:CuCu----',
#  'P-P-----:Cucr----:CuCu----',
#  'P-P-----:P-P-----:Cucr----:CuCu----',
#  'P-P-P-P-:crCuCuCu:CucrcrCu',
#  'crcrcrcr:crCuCuCu:CucrcrCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:CucrcrCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu:CucrcrCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CucrcrCu',
#  'P-P-P-P-:P-CuCuCu:Cu----Cu',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:Cu----Cu',
#  'P-Cu----:CuCuCuCu',
#  'P-P-----:P-Cu----:CuCuCuCu',
#  'P-P-----:P-P-----:P-Cu----:CuCuCuCu',
#  '----P---:----P---:----Cu--:----CuCu',
#  'P-CuCuCu',
#  'P-CuCuCu:--CuP-P-',
#  'P-P-P-P-:P-CuCuCu:--CuP-P-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:--CuP-P-',
#  'P-CuCuCu:CuP-P---',
#  'P-P-P-P-:P-CuCuCu:CuP-P---',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:CuP-P---',
#  'P-CuCuCu:P-P---Cu',
#  'P-P-P-P-:P-CuCuCu:P-P---Cu',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P-P---Cu',
#  'P-CuCuCu:P---CuP-',
#  'P-P-P-P-:P-CuCuCu:P---CuP-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P---CuP-',
#  'P-CuCuCu:--CuP---',
#  'P-P-P-P-:P-CuCuCu:--CuP---',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:--CuP---',
#  'P-CuCuCu:CuP-----',
#  'P-P-P-P-:P-CuCuCu:CuP-----',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:CuP-----',
#  'P-CuCuCu:P-----Cu',
#  'P-P-P-P-:P-CuCuCu:P-----Cu',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:P-----Cu',
#  'P-CuCuCu:----CuP-',
#  'P-P-P-P-:P-CuCuCu:----CuP-',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:----CuP-',
#  'P-CuCuCu:CuCuCuCu',
#  'crCuCuCu:CuCuCuCu',
#  'P-P-P-P-:crCuCuCu:CuCuCuCu',
#  'crcrcrcr:crCuCuCu:CuCuCuCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:CuCuCuCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu:CuCuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CuCuCuCu',
#  'P-P-P-P-:P-CuCuCu:CuCuCuCu',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:CuCuCuCu',
#  'crCuCuCu',
#  'crCuCuCu:CuCuCuP-',
#  'Cucr----:P-Cu----',
#  'P-P-----:Cucr----:P-Cu----',
#  'P-P-----:P-P-----:Cucr----:P-Cu----',
#  'crCuCuCu:CuCuCucr',
#  'Cucr----:crCu----',
#  '--Cu----:--cr----',
#  '--P-----:--Cu----:--cr----',
#  '--P-----:--P-----:--Cu----:--cr----',
#  'P-P-----:Cucr----:crCu----',
#  'P-P-----:P-P-----:Cucr----:crCu----',
#  '----CuCu:----Cucr',
#  '----P-P-:----CuCu:----Cucr',
#  '----P-P-:----P-P-:----CuCu:----Cucr',
#  'P-P-P-P-:crCuCuCu:CuCuCucr',
#  'crcrcrcr:crCuCuCu:CuCuCucr',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:CuCuCucr',
#  'crcrcrcr:crcrcrcr:crCuCuCu:CuCuCucr',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CuCuCucr',
#  'P-P-P-P-:crCuCuCu:CuCuCuP-',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CuCuCuP-',
#  'crCuCuCu:CuCuP-Cu',
#  'crCuCuCu:CuCucrCu',
#  '----CuCu:----crCu',
#  '----P-P-:----CuCu:----crCu',
#  '----P-P-:----P-P-:----CuCu:----crCu',
#  'P-P-P-P-:crCuCuCu:CuCucrCu',
#  'crcrcrcr:crCuCuCu:CuCucrCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:CuCucrCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu:CuCucrCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CuCucrCu',
#  'P-P-P-P-:crCuCuCu:CuCuP-Cu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CuCuP-Cu',
#  'crCuCuCu:CuP-CuCu',
#  'crCu----:CuP-----',
#  'P-P-----:crCu----:CuP-----',
#  'P-P-----:P-P-----:crCu----:CuP-----',
#  'crCuCuCu:CucrCuCu',
#  'crCu----:Cucr----',
#  'P-P-----:crCu----:Cucr----',
#  'P-P-----:P-P-----:crCu----:Cucr----',
#  'P-P-P-P-:crCuCuCu:CucrCuCu',
#  'crcrcrcr:crCuCuCu:CucrCuCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:CucrCuCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu:CucrCuCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CucrCuCu',
#  'P-P-P-P-:crCuCuCu:CuP-CuCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CuP-CuCu',
#  'crCuCuCu:P-CuCuCu',
#  'Cucr----:CuP-----',
#  '----cr--:----P---',
#  '----P---:----cr--:----P---',
#  '----P---:----P---:----cr--:----P---',
#  'P-P-----:Cucr----:CuP-----',
#  'P-P-----:P-P-----:Cucr----:CuP-----',
#  'crCu----:P-Cu----',
#  'P-P-----:crCu----:P-Cu----',
#  'P-P-----:P-P-----:crCu----:P-Cu----',
#  'crCuCuCu:crCuCuCu',
#  'Cucr----:Cucr----',
#  '----cr--:----cr--',
#  '----P---:----cr--:----cr--',
#  '----P---:----P---:----cr--:----cr--',
#  'P-P-----:Cucr----:Cucr----',
#  'P-P-----:P-P-----:Cucr----:Cucr----',
#  'P-P-----:P-P-----:Cu------:Cucr----',
#  'crCu----:crCu----',
#  'P-P-----:crCu----:crCu----',
#  'P-P-----:P-P-----:crCu----:crCu----',
#  'P-P-----:P-P-----:--Cu----:crCu----',
#  'P-P-P-P-:crCuCuCu:crCuCuCu',
#  'crcrcrcr:crCuCuCu:crCuCuCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:crCuCuCu',
#  'crcrcrcr:crCuCuCu:crcrcrcr:crCuCuCu',
#  'crCuCuCu:crcrcrcr:crcrcrcr:crCuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:crCuCuCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu:crCuCuCu',
#  'P-P-P-P-:crCuCuCu:P-CuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:P-CuCuCu',
#  'crCuCuCu:--CuP-P-',
#  'Cucr----:P-------',
#  '----cr--',
#  'CuP-crCu:CuCuCu--',
#  '----P-cr:----CuCu',
#  '----P-P-:----P-cr:----CuCu',
#  '----P-P-:----P-P-:----P-cr:----CuCu',
#  '----P-P-:----P-P-:----P-P-:----P-cr',
#  'CucrcrCu:CuCuCucr',
#  '------Cu:----Cucr',
#  '------P-:------Cu:----Cucr',
#  '------P-:------P-:------Cu:----Cucr',
#  'P-P-P-P-:CucrcrCu:CuCuCucr',
#  '----P-P-:------Cu:----Cucr',
#  '----P-P-:----P-P-:------Cu:----Cucr',
#  'crcrcrcr:CucrcrCu:CuCuCucr',
#  'P-P-P-P-:crcrcrcr:CucrcrCu:CuCuCucr',
#  'crcrcrcr:crcrcrcr:CucrcrCu:CuCuCucr',
#  'P-P-P-P-:P-P-P-P-:crcrcrcr:CucrcrCu',
#  'P-P-P-P-:P-P-P-P-:CucrcrCu:CuCuCucr',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:CucrcrCu',
#  'P-P-P-P-:CuP-crCu:CuCuCu--',
#  'P-P-P-P-:P-P-P-P-:CuP-crCu:CuCuCu--',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:CuP-crCu',
#  'CuP-crCu:CuCu--Cu',
#  '----P-cr:----Cu--',
#  '----P-P-:----P-cr:----Cu--',
#  '----P-P-:----P-P-:----P-cr:----Cu--',
#  'P-------:P-------:cr------',
#  'CucrcrCu:CuCucrCu',
#  'P-P-P-P-:CucrcrCu:CuCucrCu',
#  'crcrcrcr:CucrcrCu:CuCucrCu',
#  'P-P-P-P-:crcrcrcr:CucrcrCu:CuCucrCu',
#  'crcrcrcr:CucrcrCu:crcrcrcr:CuCucrCu',
#  'CucrcrCu:crcrcrcr:crcrcrcr:CuCucrCu',
#  'P-P-P-P-:P-P-P-P-:CucrcrCu:CuCucrCu',
#  'crcrcrcr:crcrcrcr:CucrcrCu:CuCucrCu',
#  'P-P-P-P-:CuP-crCu:CuCu--Cu',
#  '----P-P-:----crCu:------Cu',
#  '----P-P-:----P-P-:----crCu:------Cu',
#  'P-P-P-P-:P-P-P-P-:CuP-crCu:CuCu--Cu',
#  'CuP-crCu:Cu--CuCu',
#  '----P-cr:------Cu',
#  '----P-P-:----P-cr:------Cu',
#  '----P-P-:----P-P-:----P-cr:------Cu',
#  'CucrcrCu:CucrCuCu',
#  'P-P-P-P-:CucrcrCu:CucrCuCu',
#  'crcrcrcr:CucrcrCu:CucrCuCu',
#  'P-P-P-P-:crcrcrcr:CucrcrCu:CucrCuCu',
#  'crcrcrcr:CucrcrCu:crcrcrcr:CucrCuCu',
#  'CucrcrCu:crcrcrcr:crcrcrcr:CucrCuCu',
#  'P-P-P-P-:P-P-P-P-:CucrcrCu:CucrCuCu',
#  'crcrcrcr:crcrcrcr:CucrcrCu:CucrCuCu',
#  'P-P-P-P-:CuP-crCu:Cu--CuCu',
#  'P-P-P-P-:P-P-P-P-:CuP-crCu:Cu--CuCu',
#  'CuP-crCu:--CuCuCu',
#  'CucrcrCu:crCuCuCu',
#  'Cu------:crCu----',
#  'P-------:Cu------:crCu----',
#  'P-------:P-------:Cu------:crCu----',
#  'P-P-P-P-:CucrcrCu:crCuCuCu',
#  'P-P-----:Cu------:crCu----',
#  'P-P-----:P-P-----:Cu------:crCu----',
#  'crcrcrcr:CucrcrCu:crCuCuCu',
#  'P-P-P-P-:crcrcrcr:CucrcrCu:crCuCuCu',
#  'crcrcrcr:crcrcrcr:CucrcrCu:crCuCuCu',
#  'P-P-P-P-:P-P-P-P-:CucrcrCu:crCuCuCu',
#  'P-P-P-P-:CuP-crCu:--CuCuCu',
#  'P-P-P-P-:P-P-P-P-:CuP-crCu:--CuCuCu',
#  'crCucrCu',
#  'crCucr--',
#  'crCucrP-:Cu--Cu--',
#  '----crP-:----Cu--',
#  '----P-P-:----crP-:----Cu--',
#  '----P-P-:----P-P-:----crP-:----Cu--',
#  '----P-P-:----P-P-:----P-P-:----crP-',
#  'crCucrcr:CucrCucr',
#  'P-P-P-P-:crCucrcr:CucrCucr',
#  'crcrcrcr:crCucrcr:CucrCucr',
#  'P-P-P-P-:crcrcrcr:crCucrcr:CucrCucr',
#  'crcrcrcr:crCucrcr:crcrcrcr:CucrCucr',
#  'crCucrcr:crcrcrcr:crcrcrcr:CucrCucr',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:CucrCucr',
#  'crcrcrcr:crcrcrcr:crCucrcr:CucrCucr',
#  'P-P-P-P-:crCucrP-:Cu--Cu--',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:Cu--Cu--',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:crCucrP-',
#  'crCucrP-:--Cu--Cu',
#  '----Cucr:----Cu--',
#  '----P-P-:----Cucr:----Cu--',
#  '----P-P-:----P-P-:----Cucr:----Cu--',
#  '----crP-:------Cu',
#  '----P-P-:----crP-:------Cu',
#  '----P-P-:----P-P-:----crP-:------Cu',
#  'crCucrcr:crCucrCu',
#  'P-P-P-P-:crCucrcr:crCucrCu',
#  'crcrcrcr:crCucrcr:crCucrCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:crCucrCu',
#  'crcrcrcr:crCucrcr:crcrcrcr:crCucrCu',
#  'crCucrcr:crcrcrcr:crcrcrcr:crCucrCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:crCucrCu',
#  'crcrcrcr:crcrcrcr:crCucrcr:crCucrCu',
#  'P-P-P-P-:crCucrP-:--Cu--Cu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:--Cu--Cu',
#  'crCucrP-:CuCuCu--',
#  'crCucrcr:CuCuCucr',
#  'P-P-P-P-:crCucrcr:CuCuCucr',
#  'crcrcrcr:crCucrcr:CuCuCucr',
#  'P-P-P-P-:crcrcrcr:crCucrcr:CuCuCucr',
#  'crcrcrcr:crCucrcr:crcrcrcr:CuCuCucr',
#  'crCucrcr:crcrcrcr:crcrcrcr:CuCuCucr',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:CuCuCucr',
#  'crcrcrcr:crcrcrcr:crCucrcr:CuCuCucr',
#  'P-P-P-P-:crCucrP-:CuCuCu--',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:CuCuCu--',
#  'crCucrP-:CuCu--Cu',
#  'crCucrcr:CuCucrCu',
#  'P-P-P-P-:crCucrcr:CuCucrCu',
#  'crcrcrcr:crCucrcr:CuCucrCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:CuCucrCu',
#  'crcrcrcr:crCucrcr:crcrcrcr:CuCucrCu',
#  'crCucrcr:crcrcrcr:crcrcrcr:CuCucrCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:CuCucrCu',
#  'crcrcrcr:crcrcrcr:crCucrcr:CuCucrCu',
#  'P-P-P-P-:crCucrP-:CuCu--Cu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:CuCu--Cu',
#  'crCucrP-:Cu--CuCu',
#  '----crP-:----CuCu',
#  '----P-P-:----crP-:----CuCu',
#  '----P-P-:----P-P-:----crP-:----CuCu',
#  'crCucrcr:CucrCuCu',
#  'P-P-P-P-:crCucrcr:CucrCuCu',
#  'crcrcrcr:crCucrcr:CucrCuCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:CucrCuCu',
#  'crcrcrcr:crcrcrcr:crCucrcr:CucrCuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:CucrCuCu',
#  'P-P-P-P-:crCucrP-:Cu--CuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:Cu--CuCu',
#  'crCucrP-:--CuCuCu',
#  'crCucrcr:crCuCuCu',
#  'P-P-P-P-:crCucrcr:crCuCuCu',
#  'crcrcrcr:crCucrcr:crCuCuCu',
#  'P-P-P-P-:crcrcrcr:crCucrcr:crCuCuCu',
#  'crcrcrcr:crCucrcr:crcrcrcr:crCuCuCu',
#  'crCucrcr:crcrcrcr:crcrcrcr:crCuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrcr:crCuCuCu',
#  'crcrcrcr:crcrcrcr:crCucrcr:crCuCuCu',
#  'P-P-P-P-:crCucrP-:--CuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:--CuCuCu',
#  'crCucrP-:CuCuCuP-',
#  'P-cr----:P-Cu----',
#  'P-P-----:P-cr----:P-Cu----',
#  'P-P-----:P-P-----:P-cr----:P-Cu----',
#  '----crP-:----CuP-',
#  '----P-P-:----crP-:----CuP-',
#  '----P-P-:----P-P-:----crP-:----CuP-',
#  'P-P-P-P-:crCucrP-:CuCuCuP-',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:CuCuCuP-',
#  'crCucrP-:CuCuP-Cu',
#  '----crP-:----P-Cu',
#  '----P-P-:----crP-:----P-Cu',
#  '----P-P-:----P-P-:----crP-:----P-Cu',
#  'P-P-P-P-:crCucrP-:CuCuP-Cu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:CuCuP-Cu',
#  'crCucrP-:CuP-CuCu',
#  'P-P-P-P-:crCucrP-:CuP-CuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:CuP-CuCu',
#  'crCucrP-:P-CuCuCu',
#  'P-cr----:CuP-----',
#  'P-P-----:P-cr----:CuP-----',
#  'P-P-----:P-P-----:P-cr----:CuP-----',
#  'P-P-P-P-:crCucrP-:P-CuCuCu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:P-CuCuCu',
#  'crCucrP-:--CuP-P-',
#  'P-cr----:P-------',
#  'P-P-----:P-cr----:P-------',
#  'P-P-----:P-P-----:P-cr----:P-------',
#  '----crP-:----P-P-',
#  '----P-P-:----crP-:----P-P-',
#  '----P-P-:----P-P-:----crP-:----P-P-',
#  'P-P-P-P-:crCucrP-:--CuP-P-',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:--CuP-P-',
#  'crCucrP-:CuP-P---',
#  '----Cucr:----P-P-',
#  '----P-P-:----Cucr:----P-P-',
#  '----P-P-:----P-P-:----Cucr:----P-P-',
#  '----crP-:----P---',
#  '----P-P-:----crP-:----P---',
#  '----P-P-:----P-P-:----crP-:----P---',
#  'P-P-P-P-:crCucrP-:CuP-P---',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:CuP-P---',
#  'crCucrP-:P-P---Cu',
#  'crCu----:P-P-----',
#  'P-P-----:crCu----:P-P-----',
#  'P-P-----:P-P-----:crCu----:P-P-----',
#  'P-P-P-P-:crCucrP-:P-P---Cu',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:P-P---Cu',
#  '----P-P-:----P-P-:----Cucr:----P---',
#  'crCucrP-:P---CuP-',
#  'P-cr----:P-P-----',
#  'P-P-----:P-cr----:P-P-----',
#  'P-P-----:P-P-----:P-cr----:P-P-----',
#  'crCu----:P-------',
#  'P-P-----:crCu----:P-------',
#  'P-P-----:P-P-----:crCu----:P-------',
#  'P-P-P-P-:crCucrP-:P---CuP-',
#  'P-P-P-P-:P-P-P-P-:crCucrP-:P---CuP-',
#  'crCucrP-:--CuP---',
#  'P-cr----',
#  'P-crCuCu:Cu------',
#  'crcrCuCu:Cucrcrcr',
#  'P-P-P-P-:crcrCuCu:Cucrcrcr',
#  'crcrcrcr:crcrCuCu:Cucrcrcr',
#  'P-P-P-P-:crcrcrcr:crcrCuCu:Cucrcrcr',
#  'crcrcrcr:crcrCuCu:crcrcrcr:Cucrcrcr',
#  'crcrCuCu:crcrcrcr:crcrcrcr:Cucrcrcr',
#  'P-P-P-P-:P-P-P-P-:crcrCuCu:Cucrcrcr',
#  'crcrcrcr:crcrcrcr:crcrCuCu:Cucrcrcr',
#  'P-P-P-P-:P-crCuCu:Cu------',
#  '----P-P-:----crCu',
#  '----P-P-:----P-P-:----crCu',
#  'P-P-P-P-:P-P-P-P-:P-crCuCu:Cu------',
#  'P-crCuCu:------Cu',
#  'P-P-P-P-:P-crCuCu:------Cu',
#  'P-P-P-P-:P-P-P-P-:P-crCuCu:------Cu',
#  'P-P-----:P-P-----:P-cr----',
#  'P-crCuCu:----Cu--',
#  'P-P-P-P-:P-crCuCu:----Cu--',
#  'P-P-P-P-:P-P-P-P-:P-crCuCu:----Cu--',
#  'P-crCuCu:--Cu----',
#  'crcrCuCu:crCucrcr',
#  'P-P-P-P-:crcrCuCu:crCucrcr',
#  'crcrcrcr:crcrCuCu:crCucrcr',
#  'P-P-P-P-:crcrcrcr:crcrCuCu:crCucrcr',
#  'crcrcrcr:crcrCuCu:crcrcrcr:crCucrcr',
#  'crcrCuCu:crcrcrcr:crcrcrcr:crCucrcr',
#  'P-P-P-P-:P-P-P-P-:crcrCuCu:crCucrcr',
#  'crcrcrcr:crcrcrcr:crcrCuCu:crCucrcr',
#  'P-P-P-P-:P-crCuCu:--Cu----',
#  'P-P-P-P-:P-P-P-P-:P-crCuCu:--Cu----',
#  'P-crCuCu:Cu--Cu--',
#  'crcrCuCu:CucrCucr',
#  'crcr----:Cucr----',
#  'P-P-----:crcr----:Cucr----',
#  'P-P-----:P-P-----:crcr----:Cucr----',
#  'P-P-P-P-:crcrCuCu:CucrCucr',
#  'crcrcrcr:crcrCuCu:CucrCucr',
#  'P-P-P-P-:crcrcrcr:crcrCuCu:CucrCucr',
#  'crcrcrcr:crcrCuCu:crcrcrcr:CucrCucr',
#  'crcrCuCu:crcrcrcr:crcrcrcr:CucrCucr',
#  'P-P-P-P-:P-P-P-P-:crcrCuCu:CucrCucr',
#  'crcrcrcr:crcrcrcr:crcrCuCu:CucrCucr',
#  'P-P-P-P-:P-crCuCu:Cu--Cu--',
#  'P-P-P-P-:P-P-P-P-:P-crCuCu:Cu--Cu--',
#  'P-crCuCu:--Cu--Cu',
#  'crcrCuCu:crCucrCu',
#  'crcr----:crCu----',
#  'P-P-----:crcr----:crCu----',
#  'P-P-----:P-P-----:crcr----:crCu----',
#  'P-P-P-P-:crcrCuCu:crCucrCu',
#  'crcrcrcr:crcrCuCu:crCucrCu',
#  'P-P-P-P-:crcrcrcr:crcrCuCu:crCucrCu',
#  'crcrcrcr:crcrCuCu:crcrcrcr:crCucrCu',
#  'crcrCuCu:crcrcrcr:crcrcrcr:crCucrCu',
#  'P-P-P-P-:P-P-P-P-:crcrCuCu:crCucrCu',
#  'crcrcrcr:crcrcrcr:crcrCuCu:crCucrCu',
#  'P-P-P-P-:P-crCuCu:--Cu--Cu',
#  'P-P-P-P-:P-P-P-P-:P-crCuCu:--Cu--Cu',
#  'P-crcrCu',
#  'P-CuCuCu:Cu------',
#  'P-P-P-P-:P-CuCuCu:Cu------',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:Cu------',
#  'P-CuCuCu:------Cu',
#  'P-P-P-P-:P-CuCuCu:------Cu',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:------Cu',
#  'P-CuCuCu:----Cu--',
#  'P-P-P-P-:P-CuCuCu:----Cu--',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:----Cu--',
#  'P-CuCuCu:--Cu----',
#  'P-P-P-P-:P-CuCuCu:--Cu----',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:--Cu----',
#  'P-CuCuCu:Cu--Cu--',
#  'crCuCuCu:CucrCucr',
#  'P-P-P-P-:crCuCuCu:CucrCucr',
#  'crcrcrcr:crCuCuCu:CucrCucr',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:CucrCucr',
#  'crcrcrcr:crcrcrcr:crCuCuCu:CucrCucr',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:CucrCucr',
#  'P-P-P-P-:P-CuCuCu:Cu--Cu--',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:Cu--Cu--',
#  'P-CuCuCu:--Cu--Cu',
#  'crCuCuCu:crCucrCu',
#  'P-P-P-P-:crCuCuCu:crCucrCu',
#  'crcrcrcr:crCuCuCu:crCucrCu',
#  'P-P-P-P-:crcrcrcr:crCuCuCu:crCucrCu',
#  'crcrcrcr:crCuCuCu:crcrcrcr:crCucrCu',
#  'crCuCuCu:crcrcrcr:crcrcrcr:crCucrCu',
#  'P-P-P-P-:P-P-P-P-:crCuCuCu:crCucrCu',
#  'crcrcrcr:crcrcrcr:crCuCuCu:crCucrCu',
#  'P-P-P-P-:P-CuCuCu:--Cu--Cu',
#  'P-P-P-P-:P-P-P-P-:P-CuCuCu:--Cu--Cu',
#  'P-Cucr--',
#  'P-Cu--Cu',
#  'P-crP-Cu',
#  'P-crP-Cu:Cu--CuP-',
#  'P-P-P-P-:P-crP-Cu:Cu--CuP-',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:Cu--CuP-',
#  'P-P-P-P-:P-P-P-P-:P-P-P-P-:P-crP-Cu',
#  'P-crP-Cu:--CuP-Cu',
#  'P-P-P-P-:P-crP-Cu:--CuP-Cu',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:--CuP-Cu',
#  'P-crP-Cu:CuP-Cu--',
#  'P-P-P-P-:P-crP-Cu:CuP-Cu--',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:CuP-Cu--',
#  'P-crP-Cu:P-Cu--Cu',
#  'P-P-P-P-:P-crP-Cu:P-Cu--Cu',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:P-Cu--Cu',
#  'P-cr--Cu',
#  'P-crP-Cu:--P-CuP-',
#  'P-cr----:--P-----',
#  'P-P-----:P-cr----:--P-----',
#  'P-P-----:P-P-----:P-cr----:--P-----',
#  'P-P-P-P-:P-crP-Cu:--P-CuP-',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:--P-CuP-',
#  'P-crP-Cu:P-CuP---',
#  'P-P-P-P-:P-crP-Cu:P-CuP---',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:P-CuP---',
#  'P-crP-Cu:CuP---P-',
#  'P-P-P-P-:P-crP-Cu:CuP---P-',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:CuP---P-',
#  'P-crP-Cu:P---P-Cu',
#  '----crP-:------P-',
#  '----P-P-:----crP-:------P-',
#  '----P-P-:----P-P-:----crP-:------P-',
#  'P-P-P-P-:P-crP-Cu:P---P-Cu',
#  'P-P-P-P-:P-P-P-P-:P-crP-Cu:P---P-Cu',
#  'P-cr--Cu:--P-----',
#  'P-P---P-:P-cr--Cu:--P-----',
#  'P-P---P-:P-P---P-:P-cr--Cu:--P-----',
#  'P-P---P-:P-P---P-:P-P---P-:P-cr--Cu',
#  'P-cr--Cu:P-------',
#  'P-P---P-:P-cr--Cu:P-------',
#  'P-P---P-:P-P---P-:P-cr--Cu:P-------',
#  'P-cr--Cu:--CuCu--',
#  'P-P---P-:P-cr--Cu:--CuCu--',
#  '----P---:----cr--:----CuCu',
#  '----P---:----P---:----cr--:----CuCu',
#  ...]

# %%
# search_exact_shape('CuCu----:CuCuCuCu')


def searchShape( shapeCode):
    res = None
    a = MShape(shapeCode)
    res = search_exact_shape(a.toCode())
    if res is None:
        a = a.rotC()
        res = search_exact_shape(a.toCode())
    if res is None:
        a = a.rotC()
        res = search_exact_shape(a.toCode())
    if res is None:
        a = a.rotC()
        res = search_exact_shape(a.toCode())
    return res

def searchChild( shapeCode):
    res = None
    a = MShape(shapeCode)
    res = search_parent_shape(a.toCode())
    if res is None:
        a = a.rotC()
        res = search_parent_shape(a.toCode())
    if res is None:
        a = a.rotC()
        res = search_parent_shape(a.toCode())
    if res is None:
        a = a.rotC()
        res = search_parent_shape(a.toCode())
    return res

# search_parent_shape


# searchShape('CuCu----:CuCuCuCu:CuCu----')
# searchShape('CuCu----:CuCuCuCu')
len(searchChild('CuCu----:CuCuCuCu'))
# Out:
# 48

# %%
searchShape('CuCu----:CuCuCuCu:CuCu----')
# Out:
# {'shapeCode': '----CuCu:CuCuCuCu:----CuCu',
#  'op': 'stack',
#  'nlayer': 3,
#  'parentA': '----CuCu:CuCuCuCu',
#  'rotationA': 0,
#  'parentB': '----CuCu',
#  'rotationB': 0,
#  'ischeck': 1,
#  'opindex': 0}

# %%
def print_db() -> None:
    cur.execute('''
        SELECT * FROM key_value_store
        WHERE nlayer = 1
        LIMIT 100
    ''', ())
    
    rows = cur.fetchall()
    # Print the header
    print(f"{'Key':<45}\t{'nl':<5}\t{'Op':<5}\t{'ParentA':<42}\t{'rotA':<5}\t{'ParentB':<42}\t{'rotA':<5}\t{'OpIdx':<5}\t{'IsCheck':<5}")
    print("="*115)
    
    # Print the rows
    for row in rows:
        key, nlayer, operator, opindex, parentA, rotationA, parentB, rotationB, ischeck = row
        print(f"{key:<45}\t{nlayer:<5}\t{operator:<5}\t{parentA:<42}\t{rotationA:<5}\t{parentB:<42}\t{rotationB:<5}\t{opindex:<5}\t{ischeck:<5}")

print_db()
# Out:
# Key                                          	nl   	Op   	ParentA                                   	rotA 	ParentB                                   	rotA 	OpIdx	IsCheck
# ===================================================================================================================
# CuCuCuCu                                     	1    	start	                                          	0    	                                          	0    	0    	1
# ----CuCu                                     	1    	cut  	CuCuCuCu                                  	0    	                                          	0    	0    	1
# crcrCuCu                                     	1    	crys 	----CuCu                                  	0    	                                          	0    	0    	1
# --------                                     	1    	cut  	----CuCu                                  	0    	                                          	0    	1    	1
# ------Cu                                     	1    	cut  	----CuCu                                  	1    	                                          	0    	0    	1
# crcr----                                     	1    	cut  	crcrCuCu                                  	0    	                                          	0    	1    	1
# crcrcrcr                                     	1    	crys 	--------                                  	0    	                                          	0    	0    	1
# crcrcrCu                                     	1    	crys 	------Cu                                  	0    	                                          	0    	0    	1
# CuCu--Cu                                     	1    	swap 	------Cu                                  	0    	CuCuCuCu                                  	0    	1    	1
# P-P-CuCu                                     	1    	swap 	------Cu                                  	0    	----CuCu                                  	0    	0    	1
# ----P-Cu                                     	1    	swap 	------Cu                                  	0    	----CuCu                                  	0    	1    	1
# CuCuP-Cu                                     	1    	swap 	------Cu                                  	0    	crcrcrcr:CuCuCuCu                         	0    	1    	1
# crcrP-Cu                                     	1    	swap 	------Cu                                  	0    	crcrCuCu                                  	0    	1    	1
# P-P-----                                     	1    	swap 	------Cu                                  	0    	--------                                  	0    	0    	1
# P-P-P-Cu                                     	1    	stack	------Cu                                  	0    	--------                                  	0    	0    	1
# crcrP-P-                                     	1    	swap 	crcr----                                  	0    	crcrCuCu                                  	0    	1    	1
# crcr--Cu                                     	1    	swap 	crcr----                                  	0    	------Cu                                  	0    	0    	1
# P-P---Cu                                     	1    	swap 	crcrcrCu                                  	0    	------Cu                                  	0    	0    	1
# CuCucrCu                                     	1    	crys 	CuCu--Cu                                  	0    	                                          	0    	0    	1
# CuP-----                                     	1    	cut  	P-P-CuCu                                  	1    	                                          	0    	1    	1
# ------P-                                     	1    	cut  	----P-Cu                                  	1    	                                          	0    	0    	1
# P-P-P-P-                                     	1    	stack	P-P-----                                  	0    	--------                                  	0    	0    	1
# ----crCu                                     	1    	cut  	CuCucrCu                                  	0    	                                          	0    	0    	1
# ----Cucr                                     	1    	cut  	CuCucrCu                                  	1    	                                          	0    	0    	1
# P-P-crCu                                     	1    	swap 	CuCucrCu                                  	0    	P-P-CuCu                                  	0    	1    	1
# CuP---Cu                                     	1    	swap 	CuP-----                                  	0    	------Cu                                  	0    	0    	1
# CuP-crCu                                     	1    	swap 	CuP-----                                  	0    	CuCucrCu                                  	0    	0    	1
# CuCu--P-                                     	1    	swap 	------P-                                  	0    	CuCuCuCu                                  	0    	1    	1
# crcr--P-                                     	1    	swap 	------P-                                  	0    	crcrCuCu                                  	0    	1    	1
# crcrCuP-                                     	1    	swap 	------P-                                  	0    	crcr----                                  	0    	1    	1
# CuP-CuP-                                     	1    	swap 	------P-                                  	0    	CuP-----                                  	0    	1    	1
# P-P---P-                                     	1    	swap 	P-P-P-P-                                  	0    	------P-                                  	0    	0    	1
# ------cr                                     	1    	cut  	----crCu                                  	1    	                                          	0    	0    	1
# P-P-Cucr                                     	1    	swap 	----Cucr                                  	0    	P-P-CuCu                                  	0    	1    	1
# CuP-Cucr                                     	1    	swap 	----Cucr                                  	0    	CuP-----                                  	0    	1    	1
# ----P-cr                                     	1    	cut  	P-P-crCu                                  	1    	                                          	0    	0    	1
# --Cu--Cu                                     	1    	swap 	crcrcrCu:crCuCuCu                         	0    	------Cu                                  	0    	0    	1
# CuP---P-                                     	1    	swap 	CuP---Cu                                  	0    	------P-                                  	0    	0    	1
# CucrCucr                                     	1    	crys 	CuP-CuP-                                  	0    	                                          	0    	0    	1
# crcrCu--                                     	1    	swap 	CuCucrcr:crCucrcr:CuCuCucr                	0    	crcrCuCu                                  	0    	1    	1
# CuCu--cr                                     	1    	swap 	------cr                                  	0    	CuCuCuCu                                  	0    	1    	1
# crcr--cr                                     	1    	swap 	------cr                                  	0    	crcrCuCu                                  	0    	1    	1
# crP-----                                     	1    	cut  	P-P-Cucr                                  	1    	                                          	0    	1    	1
# P-P---cr                                     	1    	swap 	P-P-Cucr                                  	0    	------cr                                  	0    	0    	1
# CuP---cr                                     	1    	swap 	CuP-Cucr                                  	0    	------cr                                  	0    	0    	1
# crcrP-cr                                     	1    	swap 	----P-cr                                  	0    	crcrCuCu                                  	0    	1    	1
# P-P-P-cr                                     	1    	swap 	----P-cr                                  	0    	P-P-CuCu                                  	0    	1    	1
# Cucr--Cu                                     	1    	swap 	CucrCucr                                  	0    	------Cu                                  	0    	0    	1
# CucrP-Cu                                     	1    	swap 	CucrCucr                                  	0    	----P-Cu                                  	0    	0    	1
# Cucr--P-                                     	1    	swap 	CucrCucr                                  	0    	------P-                                  	0    	0    	1
# Cucr--cr                                     	1    	swap 	CucrCucr                                  	0    	------cr                                  	0    	0    	1
# CucrP-cr                                     	1    	swap 	CucrCucr                                  	0    	----P-cr                                  	0    	0    	1
# crP---Cu                                     	1    	swap 	crP-----                                  	0    	------Cu                                  	0    	0    	0
# crP---P-                                     	1    	swap 	crP-----                                  	0    	------P-                                  	0    	0    	0
# crP-CuP-                                     	1    	swap 	crP-----                                  	0    	crcrCuP-                                  	0    	0    	0
# crP---cr                                     	1    	swap 	crP-----                                  	0    	------cr                                  	0    	0    	0
# crP-Cu--                                     	1    	swap 	crP-----                                  	0    	crcrCu--                                  	0    	0    	0
# P-P-Cu--                                     	1    	swap 	P-P---cr                                  	0    	crcrCu--                                  	0    	0    	0
# CuP-Cu--                                     	1    	swap 	CuP---cr                                  	0    	crcrCu--                                  	0    	0    	0
# --CuP-cr                                     	1    	swap 	P-P-P-cr                                  	0    	--Cu--Cu                                  	0    	1    	0
# CucrCu--                                     	1    	swap 	Cucr--Cu                                  	0    	crcrCu--                                  	0    	0    	0
